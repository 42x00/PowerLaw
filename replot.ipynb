# %%
import plotly.io as pio

fig = pio.read_json("../../Downloads/rank_vs_size.json")

# %%
fig.update_layout(width=800, height=600)

fig.data[1].update(name='α = 1', showlegend=True)

fig.update_layout(legend=dict(
    yanchor="top",
    y=0.99,
    xanchor="right",
    x=0.99
))
fig
